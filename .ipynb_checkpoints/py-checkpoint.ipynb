# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
import plotly.graph_objs as go
import plotly.express as px
import statsmodels.api as sm
import numpy as np

# %%
import sys
reload(sys)
sys.setdefaultencoding("utf-8")

# %%
file_path_facebook = r"C:\Users\WILSON\Downloads\Hack\Facebook.csv"
data_facebook = pd.read_csv(file_path_facebook, low_memory=False)
data_facebook.head()
# Out:
#    Years        Date                           Post_ID   Network Post_Type  \
# 0   2022  12/17/2022  253788558082460_5441020446025886  Facebook      Post
# 1   2019    5/4/2019  253788558082460_2001824979945467  Facebook      Post
# 2   2020    6/2/2020  253788558082460_2768996106561680  Facebook      Post
# 3   2022    5/9/2022  253788558082460_4808157902645480  Facebook      Post
# 4   2021   7/18/2021  253788558082460_3890983261029620  Facebook      Post
#
#   Content_Type       Profile           Sent_ by  \
# 0        Video  Stanbic IBTC  Damilare Oyekanmi
# 1        Photo  Stanbic IBTC
# 2        Photo  Stanbic IBTC
# 3        Photo  Stanbic IBTC  Damilare Oyekanmi
# 4        Photo  Stanbic IBTC
#
#                                                 Link  \
# 0  https://www.facebook.com/253788558082460/posts...
# 1  https://www.facebook.com/253788558082460/posts...
# 2  https://www.facebook.com/StanbicIBTC/photos/a....
# 3  https://www.facebook.com/StanbicIBTC/photos/a....
# ...

# %%
file_path_twitter = r"C:\Users\WILSON\Downloads\Hack\Twitter.csv"
data_twitter = pd.read_csv(file_path_twitter, low_memory=False)
data_twitter.head()
# Out:
#    Year             Date      Post _ID  Network Post _Type Content _Type  \
# 0  2023  7/13/2023 10:57  1.680000e+18  Twitter      Tweet         Photo
# 1  2023  7/12/2023 20:03  1.680000e+18  Twitter      Tweet          Text
# 2  2023  7/12/2023 19:00  1.680000e+18  Twitter      Tweet         Photo
# 3  2023  7/12/2023 18:20  1.680000e+18  Twitter      Tweet         Photo
# 4  2023  7/11/2023 12:50  1.680000e+18  Twitter      Tweet         Photo
#
#          Profile       Sent _by  \
# 0  '@StanbicIBTC   Sophia Amuka
# 1  '@StanbicIBTC  Blessing Ubah
# 2  '@StanbicIBTC  Blessing Ubah
# 3  '@StanbicIBTC  Blessing Ubah
# 4  '@StanbicIBTC   Sophia Amuka
#
#                                                 Link  \
# 0  https://twitter.com/StanbicIBTC/status/1679429...
# 1  https://twitter.com/StanbicIBTC/status/1679204...
# 2  https://twitter.com/StanbicIBTC/status/1679189...
# 3  https://twitter.com/StanbicIBTC/status/1679179...
# 4  https://twitter.com/StanbicIBTC/status/1678733...
#
# ...

# %%
file_path_linkedin = r"C:\Users\WILSON\Downloads\Hack\Linkedin.csv"
data_linkedin = pd.read_csv(file_path_linkedin, low_memory=False)
data_linkedin.head()
# Out:
#    Year             Date       Post_ID   Network Post_Type Content_Type  \
# 0  2023  7/13/2023 12:03  7.090000e+18  LinkedIn      Post        Photo
# 1  2023  7/12/2023 20:00  7.080000e+18  LinkedIn      Post         Text
# 2  2023  7/12/2023 19:00  7.080000e+18  LinkedIn      Post        Photo
# 3  2023  7/11/2023 14:49  7.080000e+18  LinkedIn      Post        Photo
# 4  2023   7/11/2023 9:17  7.080000e+18  LinkedIn      Post        Photo
#
#         Profile        Sent_by  \
# 0  Stanbic IBTC  Blessing Ubah
# 1  Stanbic IBTC  Blessing Ubah
# 2  Stanbic IBTC  Blessing Ubah
# 3  Stanbic IBTC  Blessing Ubah
# 4  Stanbic IBTC  Blessing Ubah
#
#                                                 Link  \
# 0  https://linkedin.com/feed/update/urn:li:share:...
# 1  https://linkedin.com/feed/update/urn:li:share:...
# 2  https://linkedin.com/feed/update/urn:li:ugcPos...
# 3  https://linkedin.com/feed/update/urn:li:share:...
# 4  https://linkedin.com/feed/update/urn:li:share:...
#
# ...

# %%
file_path_instagram = r"C:\Users\WILSON\Downloads\Hack\Instagram.csv"
data_instagram = pd.read_csv(file_path_instagram, low_memory=False)
data_instagram.head()
# Out:
#    Year             Date       Post_ID    Network Post_Type Content_Type  \
# 0  2023  1/30/2023 17:06  1.820000e+16  Instagram      Post     Carousel
# 1  2022   4/15/2022 9:04  1.800000e+16  Instagram      Post        Photo
# 2  2021  5/28/2021 20:45  1.800000e+16  Instagram      Post        Video
# 3  2023   1/4/2023 16:08  1.790000e+16  Instagram      Post     Carousel
# 4  2021  12/7/2021 18:52  1.800000e+16  Instagram      Post        Photo
#
#        Profile        Sent_by                                      Link  \
# 0  stanbicibtc                 https://www.instagram.com/p/CoC6CKBIHbV/
# 1  stanbicibtc  Blessing Ubah  https://www.instagram.com/p/CcXUQTEMRm7/
# 2  stanbicibtc                 https://www.instagram.com/p/CPbcdjygiaK/
# 3  stanbicibtc                 https://www.instagram.com/p/Cm_2oino-Me/
# 4  stanbicibtc  Blessing Ubah  https://www.instagram.com/p/CXMNAKFsjSs/
#
#                                                 Post  ...  \
# ...

# %% [markdown]
# # TWITTER VISUALIZATION AND INSIGHTS

# %% [markdown]
# ## The total Impression on twitter contents
#
# Content Types: The data consists of four content types: Link, Photo, Text, and Video.
# These content types likely represent different types of content posted on a platform (e.g., social media) or website
#
# impressions: The Impressions column represents the number of times each type of content has been viewed or seen by users.
# Impressions are often used as a measure of reach or visibility
#
#
# The data indicates that photo content on Twitter receives the highest number of impressions compared to other content types. This suggests that users frequently upload photos on Twitter, making it the most popular content format in terms of visibility

# %%
Twitter_Impression_sum = data_twitter.groupby('Content _Type')['Impressions'].sum().reset_index()

# %%
Twitter_Impression_sum
# Out:
#   Content _Type  Engagements
# 0          Link      19744.0
# 1         Photo     690333.0
# 2          Text      63911.0
# 3         Video      89062.0

# %%
plt.figure(figsize=(10, 6))  # Optional: Set the figure size

plt.bar(Twitter_Impression_sum['Content _Type'], Twitter_Impression_sum['Impressions'], color='blue')
plt.xlabel('Content _Type')
plt.ylabel('Sum of Impressions')
plt.title('Impression for each Twitter content')
plt.xticks(rotation=45)


plt.savefig('large_plot.png', dpi=300)

# %% [markdown]
# # Analysis and Insights:
#
# From the data and visualization, we can draw several insights:
#
# 1."Photo" content type has significantly higher impression compared to the other types.
# 2."Text" and "Video" content types have similar impression levels, with "Video" slightly higher than "Text."
# 3."Link" content type has the lowest impression among the four types
#
# # Recommendations:
#
# Based on the analysis, here are some recommendations:
#
# 1.Consider focusing more on "Photo" content, as it generates the highest impression.
# 2.Continue to create and share "Video" content, as it performs well compared to "Text" and "Link."
# 3.Evaluate the effectiveness of "Link" content and explore ways to improve its impression.

# %% [markdown]
# # The Total  Engagement on Twitter contents
#
#
# Engagement, in the context of Twitter,refers to the level of interaction
# and interaction-related metrics that users have with your Twitter content.
# It's a measure of how your audience interacts with your tweets and how they engage with your Twitter account

# %%
Twitter_Engagement_sum = data_twitter.groupby('Content _Type')['Engagements'].sum().reset_index()

# %%
Twitter_Engagement_sum
# Out:
#   Content _Type  Engagements
# 0          Link      19744.0
# 1         Photo     690333.0
# 2          Text      63911.0
# 3         Video      89062.0

# %%
plt.figure(figsize=(10, 6))  # Optional: Set the figure size

plt.bar(Twitter_Engagement_sum['Content _Type'], Twitter_Engagement_sum['Engagements'], color='blue')
plt.xlabel('Content _Type')
plt.ylabel('Sum of Engagements')
plt.title('Engagements for each Twitter content')
plt.xticks(rotation=45)


plt.savefig('large_plot.png', dpi=300)

# %% [markdown]
# # Observations:
#
# Based on the data and the analysis:
#
# 1.The 'Photo' content type has the highest number of engagements, significantly surpassing the other content types.
# 2.'Link' and 'Text' content types have relatively lower levels of engagement.
# 3.'Video' content also has a substantial number of engagements but is less than 'Photo.'

# %% [markdown]
# # The Total reach on Twitter contents
#
# "Reach" in the context of Twitter refers to the total number of unique users or accounts who have seen a specific tweet or a set of tweets over a given time period.
# Reach is an essential metric in social media analytics and helps measure the potential audience size for your tweets.

# %%
Twitter_Reach_sum = data_twitter.groupby('Content _Type')['Potential _Reach'].sum().reset_index()

# %%
Twitter_Reach_sum
# Out:
#   Content _Type  Potential _Reach
# 0          Link      8.268334e+07
# 1         Photo      1.673346e+09
# 2          Text      1.902564e+08
# 3         Video      2.680700e+08

# %%
plt.figure(figsize=(10, 6))  # Optional: Set the figure size

plt.bar(Twitter_Reach_sum['Content _Type'], Twitter_Reach_sum['Potential _Reach'], color='blue')
plt.xlabel('Content _Type')
plt.ylabel('Sum of Potential _Reach')
plt.title('Potential Reach for each Twitter content')
plt.xticks(rotation=45)


plt.savefig('large_plot.png', dpi=300)

# %% [markdown]
# ## Potential Reach:
#
# 1.'Potential_Reach' represents the estimated reach or audience size for each content type.
# 2.'Photo' has the highest potential reach, with approximately 1.67 billion potential views.
# 3.'Video' and 'Text' also have significant potential reach, with around 268 million and 190 million potential views, respectively.
# 4.'Link' has the lowest potential reach, with approximately 82.7 million potential views.
#
#
# ## Insights:
#
# 1.'Photo' content type appears to be the most effective in terms of potential reach, likely due to the visual nature of photos being highly engaging on social media platforms.
# 2.'Video' content also has a substantial potential reach, indicating the importance of video content in reaching a broad audience.
# 3.'Text' content type, while having a good potential reach, may not be as engaging as 'Photo' or 'Video' content.
# 4.'Link' content type has the lowest potential reach, suggesting that it may not be as effective in capturing the audience's attention.
#
#
# ## Recommendations:
#
# 1.Given the high potential reach of 'Photo' and 'Video' content, consider focusing on creating more visual and video-based content for social media campaigns.
# 2.Experiment with different content types to see which ones resonate best with the target audience and drive higher engagement.
# 3.Monitor the performance of each content type over time to adapt and optimize content strategy accordingly.

# %%
content_types = data_twitter['Content _Type'].unique()

# Create a scatter plot for each content type
plt.figure(figsize=(10, 9))

for content_type in content_types:
    content_data = data_twitter[data_twitter['Content _Type'] == content_type]
    plt.scatter(content_data['Impressions'], content_data['Potential _Reach'], label=content_type)

plt.xlabel('Impressions')
plt.ylabel('Potential _Reach')
plt.title('Impressions and Potential Reach between content on Twitter')
plt.legend(title='Content _Type')

plt.show()


content_types = data_twitter['Content _Type'].unique()

# Create a scatter plot for each content type
plt.figure(figsize=(10, 9))

for content_type in content_types:
    content_data = data_twitter[data_twitter['Content _Type'] == content_type]
    plt.scatter(content_data['Potential _Reach'], content_data['Engagements'], label=content_type)

plt.xlabel('Potential _Reach')
plt.ylabel('Engagements')
plt.title('Potential reach and Engagements between Twitter contents')
plt.legend(title='Content _Type')

plt.show()

# %% [markdown]
# # INSIGHTS
#
# ## The observation between the two scatter plots
# In the initial scatter plot, there is a positive correlation between the variables, and the data points for all content types are widely dispersed. This dispersion is particularly noticeable for the 'photo' data points, and there are no exceptional outliers in the plot.
#
# In the second scatter plot, there is also a positive correlation, and the dispersion among data points for all content types is quite pronounced

# %%
print(plt.get_backend())

from ipywidgets import widgets
# Out:
# module://ipympl.backend_nbagg

# %%
from ipywidgets import widgets

# %%
plt.figure(figsize=(8, 9))  # Optional: Set the figure size

plt.bar(data_twitter['Sent _by'], data_twitter['Profile_Clicks'], color='blue')
plt.xlabel('Sent _by')
plt.ylabel('Sum of Profile_Clicks')
plt.title('Profile_Clicks for each Twitter Users')
plt.xticks(rotation=45)


plt.savefig('large_plot.png', dpi=300)




plt.figure(figsize=(8, 9))  # Optional: Set the figure size

plt.bar(data_twitter['Sent _by'], data_twitter['Engagements'], color='blue')
plt.xlabel('Sent _by')
plt.ylabel('Sum of Engagements')
plt.title('Engagements for each Twitter Users')
plt.xticks(rotation=45)


plt.savefig('large_plot.png', dpi=300)

# %% [markdown]
# # INSIGHTS
#
#
# The visualization clearly indicates that Damilare Oyekanmi stands out as the user with the most significant profile visits in the Twitter space. This can be attributed to the fact that Damilare Oyekanmi's content generates a considerably higher level of engagement compared to other users. It's evident that there is a strong positive relationship between content engagement and profile visits, meaning that the more engagement a user's content receives, the higher the number of profile visits they tend to have

# %%
# Create a grouped boxplot
plt.figure(figsize=(15, 10))

# Group and boxplot by 'Content_Type'
data_twitter.boxplot(column=['Impressions'], by='Content _Type', patch_artist=True, vert=False)

plt.xlabel('Values')
plt.title(' summary Content distribution by impression on Twitter ')
plt.suptitle('')  # Remove the default title added by boxplot
plt.xticks(rotation=45)

plt.show()


# Create a grouped boxplot
plt.figure(figsize=(10, 6))

# Group and boxplot by 'Content_Type'
data_twitter.boxplot(column=['Potential _Reach'], by='Content _Type', patch_artist=True, vert=False)

plt.xlabel('Values')
plt.title('summary Content distribution by Potential Reach on Twitter')
plt.suptitle('')  # Remove the default title added by boxplot
plt.xticks(rotation=45)

plt.show()

# %%
color_discrete_map = {
    'Photo': 'Viridis',
    'Video': 'Cividis',
    'Text': 'Paired',
    'Link': 'Green'
}

# Create a treemap with custom colors
fig = px.treemap(data_twitter, 
                 path=['Content _Type'], 
                 values='Reactions',
                 color='Content _Type',
                 color_discrete_map=color_discrete_map,  # Assign custom colors
                 hover_data=['Comments', 'Shares'], 
                 title='Distribution of reactions between all content on Twitter')

fig.show()


color_discrete_map = {
    'Photo': 'Viridis',
    'Video': 'Cividis',
    'Text': 'Paired',
    'Link': 'Green'
}

# Create a treemap with custom colors
fig = px.treemap(data_twitter, 
                 path=['Content _Type'], 
                 values='Comments',
                 color='Content _Type',
                 color_discrete_map=color_discrete_map,  # Assign custom colors
                 hover_data=['Reactions', 'Shares'], 
                 title='Distribution of comments between all content on Twitter')

fig.show()


color_discrete_map = {
    'Photo': 'Viridis',
    'Video': 'Cividis',
    'Text': 'Paired',
    'Link': 'Green'
}

# Create a treemap with custom colors
fig = px.treemap(data_twitter, 
                 path=['Content _Type'], 
                 values='Shares',
                 color='Content _Type',
                 color_discrete_map=color_discrete_map,  # Assign custom colors
                 hover_data=['Comments', 'Reactions'], 
                 title='Distribution of shares between all content on Twitter')

fig.show()
# Out:
# <div>                            <div id="94f5280d-2c55-4e39-b285-710e31698293" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("94f5280d-2c55-4e39-b285-710e31698293")) {                    Plotly.newPlot(                        "94f5280d-2c55-4e39-b285-710e31698293",                        [{"branchvalues":"total","customdata":[["(?)","(?)","Link"],["(?)","(?)","Text"],["(?)","(?)","Video"],["(?)","(?)","Photo"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Reactions=%{value}<br>parent=%{parent}<br>id=%{id}<br>Comments=%{customdata[0]}<br>Shares=%{customdata[1]}<br>Content _Type=%{customdata[2]}<extra></extra>","ids":["Link","Text","Video","Photo"],"labels":["Link","Text","Video","Photo"],"marker":{"colors":["Green","Pa
# ...

# %% [markdown]
# # INIGHTS
#
#
# Reactions, comments, and shares vary across different types of content on Twitter. Notably, the 'photo' content type consistently outperforms other content types in terms of reactions, comments, and shares. In contrast, 'link' content consistently records the lowest levels of engagement in all three categories.
#
# This observation underscores the fact that 'photo' content enjoys both higher impressions and engagement, leading to the significant numbers of reactions, comments, and shares it receives. In essence, photos are particularly effective in capturing the audience's attention and driving interaction on the platform

# %%
# Create a heatmap (correlogram)
plt.figure(figsize=(20, 6))
sns.heatmap(data_twitter.corr(), annot=True, cmap='coolwarm', linewidths=0.4)
plt.title('Heatmap (correlogram) for Twitter ')
plt.show()

correlation_matrix = data_twitter[['Engagements', 'Impressions']].corr()

# Extract the correlation between 'Impressions' and 'Engagements'
correlation = correlation_matrix.loc['Engagements', 'Impressions']

# Create a heatmap (correlogram) for the entire correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation between Engagements and Impressions Twitter')
plt.show()

# Display the correlation value between 'Impressions' and 'Engagements'
print(f'Correlation between Engagements and Impressions on Twitter: {correlation}')


correlation_matrix = data_twitter[['Engagements', 'Potential _Reach']].corr()

# Extract the correlation between 'Engagements' and 'Potential _Reach'
correlation = correlation_matrix.loc['Engagements', 'Potential _Reach']

# Create a heatmap (correlogram) for the entire correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation between Engagements and Potential Reach on Twitter')
plt.show()

# Display the correlation value between 'Engagements' and Potential _Reach'
print(f'Correlation between Engagements and Potential _Reach on Twitter : {correlation}')


correlation_matrix = data_twitter[['Profile_Clicks', 'Potential _Reach']].corr()

# Extract the correlation between 'Profile_Clicks' and 'Potential _Reach'
correlation = correlation_matrix.loc['Profile_Clicks', 'Potential _Reach']

# Create a heatmap (correlogram) for the entire correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation between Profile Clicks and Potential Reach on Twitter')
plt.show()

# Display the correlation value between 'Profile_Clicks' and Potential _Reach'
print(f'Correlation between Profile_Clicks and Potential _Reach : {correlation}')
# Out:
# Correlation between Engagements and Impressions on Twitter: 0.6180964948397293
# Correlation between Engagements and Potential _Reach on Twitter : 0.2650595293822716
# Correlation between Profile_Clicks and Potential _Reach : 0.2290585806574463

# %% [markdown]
# # INIGHST FOR CORRELATION BETWEEN ENGAGEMENT AND IMPRESSION
#
# ## Strong Positive Correlation:
# A correlation coefficient of 0.6181 indicates a strong positive correlation between 'Engagements' and 'Impressions.' In other words, as one of these variables increases, the other tends to increase as well.
#
# ## Strength of the Correlation:
# The value of 0.6181 suggests a strong positive correlation. The closer the correlation coefficient is to 1, the stronger the positive correlation. In this case, the correlation is not only positive but also robust, indicating a clear relationship between the two variables
#
# ## Practical Interpretation:
# In practical terms, this strong positive correlation means that when a user's content on Twitter receives more engagements (such as likes, comments, shares, or other interactions), it is highly likely that the content will also generate a larger number of impressions. Impressions represent the number of times the content is displayed to users
#
# ## Causality Consideration:
# While there is a strong correlation, it's important to remember that correlation does not imply causation. In other words, while there is a clear relationship between engagements and impressions, it doesn't necessarily mean that one directly causes the other. Other factors, such as the quality of content, posting strategy, or user behavior, may also contribute to this observed relationship.
#
# In summary, a strong positive correlation coefficient of 0.6181 between 'Engagements' and 'Impressions' on Twitter indicates that there is a robust and positive relationship between the two variables. Content that receives more engagements is highly likely to generate a greater number of impressions, but causality should be considered cautiously, and other contributing factors may be at play.
#
#
# # INIGHST FOR CORRELATION BETWEEN ENGAGEMENT AND POTENTIAL REACH
#
# ## Positive Correlation:
# A correlation coefficient of 0.2651 indicates a positive correlation between 'Engagements' and 'Potential_Reach.' In other words, as one of these variables increases, the other tends to increase as well.
#
# ## Strength of the Correlation:
# The value of 0.2651 suggests a relatively weak positive correlation. The closer the correlation coefficient is to 1, the stronger the positive correlation. In this case, the correlation is positive but not very strong.
#
# ## Practical Interpretation:
# In practical terms, this positive correlation means that when a user's content on Twitter receives more engagements (such as likes, comments, shares, or other interactions), there is a tendency for their potential reach (the estimated number of people who could see their content) to increase modestly.
#
# In summary, a positive correlation coefficient of 0.2651 indicates a weak positive relationship between 'Engagements' and 'Potential_Reach' on Twitter. This suggests that as a user's content receives more engagements, there is a tendency for their potential reach to increase modestly. However, the causality of this relationship should be considered cautiously, and additional factors may be at play
#
#
# # INIGHST FOR CORRELATION BETWEEN PROFILE CLICK AND POTENTIAL REACH
#
# ## Positive Correlation:
# A correlation coefficient of 0.2291 indicates a positive correlation between 'Profile_Clicks' and 'Potential_Reach.' In other words, as one of these variables increases, the other tends to increase as well.
#
# ## Practical Interpretation:
# Practically, a positive correlation of 0.2291 between 'Profile_Clicks' and 'Potential_Reach' means that when a user's profile receives more clicks (such as clicks on their profile picture or username), there is a tendency for their potential reach (the estimated number of people who could see their content) to increase modestly.
#
# ## Strength of the Correlation:
# The value of 0.2291 suggests a relatively weak positive correlation. The closer the correlation coefficient is to 1, the stronger the positive correlation. In this case, the correlation is positive but not very strong
#
# In summary, a positive correlation coefficient of 0.2291 indicates a weak positive relationship between 'Profile_Clicks' and 'Potential_Reach,' suggesting that as profile clicks increase, there is a tendency for potential reach to increase modestly. However, it's essential to consider this correlation within the broader context of your analysis and explore potential contributing factors.

# %% [markdown]
# # INSTAGRAM ANALYSIS AND VISUALIZATION

# %%
#The Total Impression on Instagram contents

# %%
Instagram_Impression_sums = data_instagram.groupby('Content_Type')['Impressions'].sum().reset_index()

# %%
Instagram_Impression_sums
# Out:
#   Content_Type  Impressions
# 0     Carousel    1787650.0
# 1        Photo   15448570.0
# 2        Video    2127931.0

# %%
plt.figure(figsize=(10, 6))  # Optional: Set the figure size

plt.bar(Instagram_Impression_sums['Content_Type'], Instagram_Impression_sums['Impressions'], color='blue')
plt.xlabel('Content _Type')
plt.ylabel('Sum of Impressions')
plt.title('Impression for each Instagram content')
plt.xticks(rotation=45)


plt.savefig('large_plot.png', dpi=300)

# %% [markdown]
# # Content-Type Analysis:
#
# The dataset includes three content types: 'Carousel,' 'Photo,' and 'Video.'
# 'Photo' content type stands out with significantly higher impressions (15,448,570) compared to the other two types.
# 'Video' content type has the second-highest impressions (2,127,931), while 'Carousel' content type has the lowest impressions (1,787,650).
#
# # Impressions Comparison:
#
# 'Photo' content generates substantially more impressions compared to 'Carousel' and 'Video.'
# The difference in impressions between 'Photo' and 'Carousel' is notable, indicating that 'Photo' content is highly engaging or has a wider reach.
#
# # Content Strategy Insights:
#
# The data suggests that 'Photo' content is particularly effective in reaching and engaging the audience.
# Content creators or marketers may consider focusing more on 'Photo' content due to its ability to generate high impressions.
#
# In conclusion, the technical insights analysis of this data suggests that 'Photo' content type is highly effective in generating impressions on the platform. Content creators and marketers may benefit from focusing on visual content strategies, while also considering opportunities to diversify their content portfolio and continuously optimize their approach to engage and reach a wider audience.

# %%
#The Total Engagement on Instagram content

# %%
Instagram_Engagement_sums = data_instagram.groupby('Content_Type')['Engagements'].sum().reset_index()

# %%
Instagram_Engagement_sums
# Out:
#   Content_Type  Engagements
# 0     Carousel        67857
# 1        Photo       803493
# 2        Video       133281

# %%
plt.figure(figsize=(10, 6))  # Optional: Set the figure size

plt.bar(Instagram_Engagement_sums['Content_Type'], Instagram_Engagement_sums['Engagements'], color='blue')
plt.xlabel('Content _Type')
plt.ylabel('Sum of Engagements')
plt.title('Engagements for each Instagram content')
plt.xticks(rotation=45)


plt.savefig('large_plot.png', dpi=300)

# %% [markdown]
# # Content-Type Analysis:
#
# The dataset includes three content types: 'Carousel,' 'Photo,' and 'Video.'
# 'Photo' content type stands out with a significantly higher number of engagements (803,493) compared to the other two types.
# 'Video' content type has the second-highest engagements (133,281), while 'Carousel' content type has the lowest engagements (67,857).
#
# # Engagements Comparison:
#
# 'Photo' content generates substantially more engagements compared to 'Carousel' and 'Video.'
# The difference in engagements between 'Photo' and 'Carousel' is notable, indicating that 'Photo' content is highly engaging.
#
# # Content Strategy Insights:
#
# 'Photo' content is particularly effective in driving user engagements.
# Content creators or marketers may consider focusing more on 'Photo' content due to its ability to generate high levels of engagement.
#
# In conclusion, the technical insights analysis of this data suggests that 'Photo' content type is highly effective in generating user engagements on the platform. Content creators and marketers may benefit from focusing on visual content strategies, while also considering opportunities to diversify their content portfolio and continuously optimize their approach to engage with the audience effectively.

# %%
# Create a grouped boxplot
plt.figure(figsize=(10, 6))

# Group and boxplot by 'Content_Type'
data_instagram.boxplot(column=['Impressions'], by='Content_Type', patch_artist=True, vert=False)

plt.xlabel('Values')
plt.title('summary Content distribution by Impressions on Instagram')
plt.suptitle('')  # Remove the default title added by boxplot
plt.xticks(rotation=45)

plt.show()

# %%
#The Total Reach on Instagram contents

# %%
Instagram_Reach_sums = data_instagram.groupby('Content_Type')['Reach'].sum().reset_index()

# %%
Instagram_Reach_sums
# Out:
#   Content_Type       Reach
# 0     Carousel    936127.0
# 1        Photo  10192399.0
# 2        Video   1671974.0

# %%
plt.figure(figsize=(10, 6))  # Optional: Set the figure size

plt.bar(Instagram_Reach_sums['Content_Type'], Instagram_Reach_sums['Reach'], color='blue')
plt.xlabel('Content _Type')
plt.ylabel('Sum of Reach')
plt.title('Reach for each Instagram content')
plt.xticks(rotation=45)


plt.savefig('large_plot.png', dpi=300)

# %% [markdown]
# # Content-Type Analysis:
#
# The dataset includes three content types: 'Carousel,' 'Photo,' and 'Video.'
# 'Photo' content type stands out with significantly higher reach (approximately 10,192,399) compared to the other two types.
# 'Video' content type has the second-highest reach (approximately 1,671,974), while 'Carousel' content type has the lowest reach (approximately 936,127).
#
# # Reach Comparison:
#
# 'Photo' content generates substantially more reach compared to 'Carousel' and 'Video.'
# The difference in reach between 'Photo' and 'Carousel' is substantial, indicating that 'Photo' content is highly effective in reaching a larger audience.
#
# # Content Strategy Insights:
#
# 'Photo' content is particularly effective in reaching a wide audience.
# Content creators or marketers may consider focusing more on 'Photo' content due to its ability to reach a larger number of users.
#
# In conclusion, the technical insights analysis of this data suggests that 'Photo' content type is highly effective in reaching a larger audience on the platform. Content creators and marketers may benefit from emphasizing visual content strategies, while also considering opportunities to diversify their content portfolio and continuously optimize their approach to maximize content reach.

# %%
content_types = data_instagram['Content_Type'].unique()

# Create a scatter plot for each content type
plt.figure(figsize=(10, 9))

for content_type in content_types:
    content_data = data_instagram[data_instagram['Content_Type'] == content_type]
    plt.scatter(content_data['Impressions'], content_data['Reach'], label=content_type)

plt.xlabel('Impressions')
plt.ylabel('Reach')
plt.title('Impressions and Reach between content on Instagram')
plt.legend(title='Content_Type')

plt.show()

content_types = data_instagram['Content_Type'].unique()

# Create a scatter plot for each content type
plt.figure(figsize=(10, 9))

for content_type in content_types:
    content_data = data_instagram[data_instagram['Content_Type'] == content_type]
    plt.scatter(content_data['Reach'], content_data['Engagements'], label=content_type)

plt.xlabel('Reach')
plt.ylabel('Engagements')
plt.title(' Reach and Engagements between Instagram contents')
plt.legend(title='Content_Type')

plt.show()

# %% [markdown]
# # INSIGHTS
# The observation between the two scatter plots
# In the initial scatter plot, there is a positive correlation between the variables, and the data points for all content types are widely dispersed. This dispersion is particularly noticeable for the 'photo' data points, and there are no exceptional outliers in the plot.
#
# In the second scatter plot, there is also a positive correlation, and the dispersion among data points for all content types is quite pronounced

# %%
# Create a grouped boxplot
plt.figure(figsize=(10, 6))

# Group and boxplot by 'Content_Type'
data_instagram.boxplot(column=['Impressions'], by='Content_Type', patch_artist=True, vert=False)

plt.xlabel('Values')
plt.title('summary Content distribution by Impressions on Instagram')
plt.suptitle('')  # Remove the default title added by boxplot
plt.xticks(rotation=45)

plt.show()


# Create a grouped boxplot
plt.figure(figsize=(10, 6))

# Group and boxplot by 'Content_Type'
data_instagram.boxplot(column=['Impressions'], by='Content_Type', patch_artist=True, vert=False)

plt.xlabel('Values')
plt.title('summary Content distribution by Impressions on Instagram')
plt.suptitle('')  # Remove the default title added by boxplot
plt.xticks(rotation=45)

plt.show()

# %%
color_discrete_map = {
    'Photo': 'Green',
    'Video': 'Cividis',
    'Text': 'Paired',
    'Link': 'Viridis'
}

# Create a treemap with custom colors
fig = px.treemap(data_instagram, 
                 path=['Content_Type'], 
                 values='Reactions',
                 color='Content_Type',
                 color_discrete_map=color_discrete_map,  # Assign custom colors
                 hover_data=['Comments', 'Saves'], 
                 title='Distribution of reactions between all content on instagram')

fig.show()


color_discrete_map = {
    'Photo': 'Green',
    'Video': 'Cividis',
    'Text': 'Paired',
    'Link': 'Viridis'
}

# Create a treemap with custom colors
fig = px.treemap(data_instagram, 
                 path=['Content_Type'], 
                 values='Comments',
                 color='Content_Type',
                 color_discrete_map=color_discrete_map,  # Assign custom colors
                 hover_data=['Reactions', 'Saves'], 
                 title='Distribution of comments between all content on Instagram')

fig.show()


color_discrete_map = {
    'Photo': 'Green',
    'Video': 'Cividis',
    'Text': 'Paired',
    'Link': 'Viridis'
}

# Create a treemap with custom colors
fig = px.treemap(data_instagram, 
                 path=['Content_Type'], 
                 values='Saves',
                 color='Content_Type',
                 color_discrete_map=color_discrete_map,  # Assign custom colors
                 hover_data=['Comments', 'Reactions'], 
                 title='Distribution of save between all content on instagram')

fig.show()
# Out:
# <div>                            <div id="3e55d996-7646-44d6-b12d-3ae29998972d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e55d996-7646-44d6-b12d-3ae29998972d")) {                    Plotly.newPlot(                        "3e55d996-7646-44d6-b12d-3ae29998972d",                        [{"branchvalues":"total","customdata":[["(?)","(?)","Carousel"],["(?)","(?)","Photo"],["(?)","(?)","Video"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Reactions=%{value}<br>parent=%{parent}<br>id=%{id}<br>Comments=%{customdata[0]}<br>Saves=%{customdata[1]}<br>Content_Type=%{customdata[2]}<extra></extra>","ids":["Carousel","Photo","Video"],"labels":["Carousel","Photo","Video"],"marker":{"colors":["#FFA15A","Green","Cividis"]},"name"
# ...

# %% [markdown]
# # INIGHTS
#
#
# Engagement metrics like reactions, comments, and saves exhibit variations among different content types on Instagram. Specifically, 'photo' content consistently stands out as the top performer across all these engagement metrics. On the other hand, 'carousel' content consistently falls behind in comments but achieves average results in both reactions and saves
#
# This observation underscores the fact that 'photo' content enjoys both higher impressions and engagement, leading to the significant numbers of reactions, comments, and saves it receives. In essence, photos are particularly effective in capturing the audience's attention and driving interaction on the platform

# %%
# Create a heatmap (correlogram)
plt.figure(figsize=(20, 6))
sns.heatmap(data_instagram.corr(), annot=True, cmap='coolwarm', linewidths=0.4)
plt.title('Heatmap (correlogram) for Instagram ')
plt.show()

correlation_matrix = data_instagram[['Engagements', 'Impressions']].corr()

# Extract the correlation between 'Impressions' and 'Engagements'
correlation = correlation_matrix.loc['Engagements', 'Impressions']

# Create a heatmap (correlogram) for the entire correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation between Engagements and Impressions on Instagram')
plt.show()

# Display the correlation value between 'Impressions' and 'Engagements'
print(f'Correlation between Engagements and Impressions instagram : {correlation}')


correlation_matrix = data_instagram[['Engagements', 'Reach']].corr()

# Extract the correlation between 'Engagements' and 'Reach'
correlation = correlation_matrix.loc['Engagements', 'Reach']

# Create a heatmap (correlogram) for the entire correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation between Engagements and  Reach on instagram')
plt.show()

# Display the correlation value between 'Engagements' and Reach'
print(f'Correlation between Engagements and Reach on instagram : {correlation}')
# Out:
# Correlation between Engagements and Impressions instagram : 0.04272738974457156
# Correlation between Engagements and Reach on instagram : 0.03248399571868004

# %% [markdown]
# # INIGHST FOR CORRELATION BETWEEN ENGAGEMENT AND IMPRESSION
#
# ## Weak Positive Correlation:
# A correlation coefficient of 0.0427 indicates a very weak positive correlation between 'Engagements' and 'Impressions.' In other words, as one of these variables increases, the other tends to increase slightly, but the relationship is minimal.
#
# ## Strength of the Correlation:
# The value of 0.0427 suggests an almost negligible positive correlation. It is very close to zero, indicating that there is almost no meaningful relationship between engagements and impressions in this dataset.
#
# ## Limited Predictive Power:
# The correlation is so weak that it provides almost no predictive power. In other words, knowing the level of engagements on a post does not reliably tell you anything about how many impressions that post will receive, and vice versa
#
# ## Practical Interpretation:
# In practical terms, this very weak positive correlation means that there is almost no consistent or substantial connection between the number of engagements (likes, comments, shares, etc.) a piece of content receives and the number of impressions (the number of times the content is displayed) it garners on Instagram.
#
# ## Considerations:
# It's important to understand that correlation does not imply causation. Just because there is a weak correlation does not mean that engagements directly cause impressions or vice versa. Other factors and variables may influence both these metrics independently.
#
# In summary, a correlation coefficient of 0.0427 suggests an almost negligible positive relationship between 'Engagements' and 'Impressions' on Instagram. This weak correlation indicates that, in this dataset, the level of engagements on posts does not significantly or reliably predict the number of impressions, and vice versa. The factors influencing these metrics may be more complex and multifaceted.
#
# # INIGHST FOR CORRELATION BETWEEN ENGAGEMENT AND REACH
#
# ## Very Weak Positive Correlation:
# A correlation coefficient of 0.0325 indicates a very weak positive correlation between 'Engagements' and 'Reach.' In other words, as one of these variables increases, the other tends to increase slightly, but the relationship is minimal.
#
# ## Strength of the Correlation:
# The value of 0.0325 suggests an almost negligible positive correlation. It is very close to zero, indicating that there is almost no meaningful relationship between engagements (likes, comments, shares, etc.) and the reach (the number of users who saw the content) in this dataset
#
# ## Practical Interpretation:
# In practical terms, this very weak positive correlation means that there is almost no consistent or substantial connection between the level of engagements a piece of content receives and the number of users reached on Instagram
#
# ## Limited Predictive Power:
# The correlation is so weak that it provides almost no predictive power. In other words, knowing the level of engagements on a post does not reliably tell you anything about how many users that post will reach, and vice versa
#
# ## Considerations:
# It's essential to understand that correlation does not imply causation. Just because there is a weak correlation does not mean that engagements directly cause reach or vice versa. Other factors and variables may independently influence both these metrics
#
# In summary, a correlation coefficient of 0.0325 indicates an almost negligible positive relationship between 'Engagements' and 'Reach' on Instagram. This weak correlation suggests that, in this dataset, the level of engagements on posts does not significantly or reliably predict the number of users reached, and vice versa. The factors influencing these metrics may be multifaceted and more complex.

# %% [markdown]
# # LINKEDIN INSIGHTS AND VISUALIZATIONS

# %%
#The Total Impressions on Linkedin

# %%
Linkedin_Impression_sums = data_linkedin.groupby('Content_Type')['Impressions'].sum().reset_index()

# %%
Linkedin_Impression_sums
# Out:
#   Content_Type  Impressions
# 0     Document       1438.0
# 1         Link      43276.0
# 2        Photo    5392024.0
# 3         Poll      44714.0
# 4         Text     312985.0
# 5        Video    1065042.0

# %%
plt.figure(figsize=(10, 6))  # Optional: Set the figure size

plt.bar(Linkedin_Impression_sums['Content_Type'], Linkedin_Impression_sums['Impressions'], color='blue')
plt.xlabel('Content_Type')
plt.ylabel('Sum of Impressions')
plt.title('Impression for each Linkedin content')
plt.xticks(rotation=45)


plt.savefig('large_plot.png', dpi=300)

# %% [markdown]
# # INSIGHTS
#
#
# ## Content-Type Analysis:
#
# The dataset includes six different content types: 'Document,' 'Link,' 'Photo,' 'Poll,' 'Text,' and 'Video.'
# 'Photo' content type stands out with the highest number of impressions (approximately 5,392,024), indicating that photo-based content is highly engaging and generates a significant number of views.
#
# ## Impressions Comparison:
#
# 'Photo' content generates a significantly higher number of impressions compared to the other content types. It has a notably larger reach.
# 'Video' content is the second-highest in terms of impressions (approximately 1,065,042), suggesting that video content is also engaging.
# 'Text' and 'Link' content types have moderate impressions, indicating some level of engagement.
# 'Poll' and 'Document' content types have the lowest impressions, suggesting that these types of content may be less engaging or have a more niche audience.
#
# ## Content Strategy Insights:
#
# 'Photo' and 'Video' content types are particularly effective in generating high impressions, indicating that visual and multimedia content tends to perform well.
# 'Text' and 'Link' content types are moderately engaging, suggesting that well-crafted text-based posts and shared links can also attract attention.
# 'Poll' and 'Document' content types have lower impressions, which may indicate that these types of content may need optimization or may be suitable for specific purposes.
#
#
# In summary, the analysis of this data highlights the dominance of 'Photo' content in terms of impressions, indicating that visual content is highly engaging on the platform. However, there is room for diversification and optimization of content strategies, particularly for other content types such as 'Text,' 'Poll,' 'Document,' and 'Link.' Understanding audience preferences and continuously refining content strategies can lead to improved engagement and reach.

# %%
#The Total Engagement on Linkedin

# %%
Linkedin_Engagement_sums = data_linkedin.groupby('Content_Type')['Engagements'].sum().reset_index()

# %%
Linkedin_Engagement_sums
# Out:
#   Content_Type  Engagements
# 0     Document        260.0
# 1         Link       1526.0
# 2        Photo     279077.0
# 3         Poll       1230.0
# 4         Text       8064.0
# 5        Video      29264.0

# %%
plt.figure(figsize=(10, 6))  # Optional: Set the figure size

plt.bar(Linkedin_Engagement_sums['Content_Type'], Linkedin_Engagement_sums['Engagements'], color='blue')
plt.xlabel('Content _Type')
plt.ylabel('Sum of Engagements')
plt.title('Engagements for each Linkedin content')
plt.xticks(rotation=45)


plt.savefig('large_plot.png', dpi=300)

# %% [markdown]
# # INSIGHTS
#
# ## Content-Type Analysis:
#
# The dataset includes six different content types: 'Document,' 'Link,' 'Photo,' 'Poll,' 'Text,' and 'Video.'
# 'Photo' content type stands out with the highest number of engagements (approximately 279,077), indicating that photo-based content is highly engaging and generates a substantial amount of user interactions
#
# ## Engagements Comparison:
#
# 'Photo' content generates a significantly higher number of engagements compared to the other content types. It has a notably larger level of user interactions.
# 'Video' content is the second-highest in terms of engagements (approximately 29,264), suggesting that video content is also engaging.
# 'Text' and 'Link' content types have moderate engagements, indicating that well-crafted text-based posts and shared links can also attract user interactions.
# 'Poll' and 'Document' content types have the lowest engagements, suggesting that these types of content may be less engaging or have a more niche audience.
#
# ## Content Strategy Insights:
#
# 'Photo' and 'Video' content types are particularly effective in generating high engagements, indicating that visual and multimedia content tends to perform well in terms of user interactions.
# 'Text' and 'Link' content types are moderately engaging, suggesting that well-written textual content and shared links can also attract user engagement.
# 'Poll' and 'Document' content types have lower engagements, which may indicate that these types of content may need optimization or may be suitable for specific purposes.
#
# In summary, the analysis of this data highlights the dominance of 'Photo' content in terms of engagements, indicating that visual content is highly engaging and effective in generating user interactions. However, there is potential for diversification and optimization of content strategies, particularly for other content types such as 'Text,' 'Poll,' 'Document,' and 'Link.' Understanding audience preferences and continuously refining content strategies can lead to improved user engagement and interaction levels.

# %%
content_types =data_linkedin['Content_Type'].unique()

# Create a scatter plot for each content type
plt.figure(figsize=(10, 9))

for content_type in content_types:
    content_data = data_linkedin[data_instagram['Content_Type'] == content_type]
    plt.scatter(content_data['Impressions'], content_data['Engagements'], label=content_type)

plt.xlabel('Impressions')
plt.ylabel('Engagements')
plt.title('Impressions and Engagements between content on Linkedin')
plt.legend(title='Content_Type')

plt.show()
# Out:
# C:\Users\WILSON\AppData\Local\Temp/ipykernel_11780/3178026038.py:7: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# # INSIGHTS
# The observation between the two scatter plots
# In the initial scatter plot, there is a positive correlation between the variables, and the data points for all content types are widely dispersed. This dispersion is particularly noticeable for the 'photo' data points, and there are no exceptional outliers in the plot.

# %%
color_discrete_map = {
    'Photo': 'Green',
    'Video': 'Cividis',
    'Text': 'Paired',
    'Link': 'Viridis'
}

# Create a treemap with custom colors
fig = px.treemap(data_linkedin, 
                 path=['Content_Type'], 
                 values='Reactions',
                 color='Content_Type',
                 color_discrete_map=color_discrete_map,  # Assign custom colors
                 hover_data=['Comments', 'Saves','Shares'], 
                 title='Distribution of reactions between all content on Linkedin')

fig.show()


color_discrete_map = {
    'Photo': 'Green',
    'Video': 'Cividis',
    'Text': 'Paired',
    'Link': 'Viridis'
}

# Create a treemap with custom colors
fig = px.treemap(data_linkedin, 
                 path=['Content_Type'], 
                 values='Comments',
                 color='Content_Type',
                 color_discrete_map=color_discrete_map,  # Assign custom colors
                 hover_data=['Reactions', 'Saves','Shares'], 
                 title='Distribution of comments between all content on linkedin')

fig.show()







color_discrete_map = {
    'Photo': 'Green',
    'Video': 'Cividis',
    'Text': 'Paired',
    'Link': 'Viridis'
}

# Create a treemap with custom colors
fig = px.treemap(data_linkedin, 
                 path=['Content_Type'], 
                 values='Shares',
                 color='Content_Type',
                 color_discrete_map=color_discrete_map,  # Assign custom colors
                 hover_data=['Reactions', 'Comments','Saves'], 
                 title='Distribution of shares between all content on linkedin')

fig.show()
# Out:
# <div>                            <div id="7e5e03da-116a-445e-8924-ee3018f99f84" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e5e03da-116a-445e-8924-ee3018f99f84")) {                    Plotly.newPlot(                        "7e5e03da-116a-445e-8924-ee3018f99f84",                        [{"branchvalues":"total","customdata":[[0.0,null,0.0,"Document"],["(?)",null,"(?)","Photo"],["(?)",null,0.0,"Poll"],["(?)",null,"(?)","Text"],["(?)",null,"(?)","Video"],["(?)",null,"(?)","Link"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Reactions=%{value}<br>parent=%{parent}<br>id=%{id}<br>Comments=%{customdata[0]}<br>Saves=%{customdata[1]}<br>Shares=%{customdata[2]}<br>Content_Type=%{customdata[3]}<extra></extra>","ids":["Documen
# ...

# %% [markdown]
# # INSIGHTS ON REACTIONS ON LINKEDIN CONTENTS
#
# The analysis of engagement metrics, specifically reactions, across all LinkedIn content types, reveals that 'Photo' content consistently receives the highest number of reactions compared to other content types. The treemap visualization further highlights that certain content types stand out with significant levels of engagement. Notably, 'Text' and 'Link' content types have the lowest number of reactions.
#
#
# # INSIGHTS ON COMMENTS ON LINKEDIN CONTENTS
#
# The examination of engagement metrics, particularly comments, across all LinkedIn content types, indicates that 'Photo' and 'Video' content consistently attract the most comments compared to other content types. On the other hand, 'Text' content receives a moderate level of comments, while 'Link' content consistently receives the fewest comments.
#
# # INSIGHTS ON SHARES ON LINKEDIN CONTENTS
#
# The examination of engagement metrics, particularly shares, across all LinkedIn content types, indicates that 'Photo' and 'Video' content consistently attract the most comments compared to other content types. On the other hand, 'Text' and 'link'content consistently receives the fewest comments.

# %%
# Create a grouped boxplot
plt.figure(figsize=(15, 10))

# Group and boxplot by 'Content_Type'
data_linkedin.boxplot(column=['Impressions'], by='Content_Type', patch_artist=True, vert=False)

plt.xlabel('Values')
plt.title(' summary Content distribution by impression on Linkedin ')
plt.suptitle('')  # Remove the default title added by boxplot
plt.xticks(rotation=45)

plt.show()



# Create a grouped boxplot
plt.figure(figsize=(15, 10))

# Group and boxplot by 'Content_Type'
data_linkedin.boxplot(column=['Engagements'], by='Content_Type', patch_artist=True, vert=False)

plt.xlabel('Values')
plt.title(' summary Content distribution by Engagements on Linkedin ')
plt.suptitle('')  # Remove the default title added by boxplot
plt.xticks(rotation=45)

plt.show()

# %%
# Create a heatmap (correlogram)
plt.figure(figsize=(20, 6))
sns.heatmap(data_linkedin.corr(), annot=True, cmap='coolwarm', linewidths=0.4)
plt.title('Heatmap (correlogram) for linkedin ')
plt.show()

correlation_matrix = data_linkedin[['Engagements', 'Impressions']].corr()
# Extract the correlation between 'Impressions' and 'Engagements'
correlation = correlation_matrix.loc['Engagements', 'Impressions']

# Create a heatmap (correlogram) for the entire correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation between Engagements and Impressions on Linkedin')
plt.show()

# Display the correlation value between 'Impressions' and 'Engagements'
print(f'Correlation between Engagements and Impressions Linkedin : {correlation}')
# Out:
# Correlation between Engagements and Impressions Linkedin : 0.6795378780372962

# %% [markdown]
# # INSIGHTS FOR CORRELATION BETWEEN ENGAGEMENT AND IMPRESSIONS                                                 ON LINKEDIN
#
# ## Strong Positive Correlation:
# A correlation coefficient of 0.6795 indicates a strong positive correlation between 'Engagements' and 'Impressions.' In other words, as one of these variables increases, the other tends to increase significantly as well, and vice versa
#
# ## Strength of the Correlation:
# The value of 0.6795 suggests a robust and positive relationship between engagements (likes, comments, shares, etc.) and impressions (the number of times content is viewed) on LinkedIn. This means that when a piece of content generates more engagements, it also tends to achieve a higher number of impressions, and when it receives fewer engagements, it has fewer impressions.
#
# ## Predictive Power:
# The strong correlation provides predictive power. This means that knowing the level of engagements on a LinkedIn post can reliably predict how many impressions that post is likely to achieve, and vice versa. If a post receives a high level of engagements, it is more likely to reach a broader audience.
#
# In summary, a correlation coefficient of 0.6795 indicates a strong positive relationship between 'Engagements' and 'Impressions' on LinkedIn. This suggests that, on the LinkedIn platform, content that generates higher levels of user engagements is highly likely to achieve a greater number of impressions, and vice versa. Understanding and leveraging this correlation can be valuable for content strategy and optimization on LinkedIn.

# %% [markdown]
# # FACEBOOK INSIGHTS AND VISUALIZATION

# %%
#The Total Impressions on Facebook

# %%
Facebook_Impression_sums = data_facebook.groupby('Content_Type')['Impressions'].sum().reset_index()

# %%
Facebook_Impression_sums
# Out:
#   Content_Type  Impressions
# 0         Link     361718.0
# 1        Photo   47446005.0
# 2         Text    2071234.0
# 3        Video    2213793.0

# %%
plt.figure(figsize=(10, 6))  # Optional: Set the figure size

plt.bar(Facebook_Impression_sums['Content_Type'], Facebook_Impression_sums['Impressions'], color='blue')
plt.xlabel('Content_Type')
plt.ylabel('Sum of Impressions')
plt.title('Impression for each facebook content')
plt.xticks(rotation=45)


plt.savefig('large_plot.png', dpi=300)

# %% [markdown]
# # INSIGHTS
#
# # Content-Type Analysis:
#
# The dataset includes four different content types: 'Link,' 'Photo,' 'Text,' and 'Video.'
# 'Photo' content stands out with the highest number of impressions (approximately 47,446,005), indicating that photo-based content is exceptionally effective in terms of generating impressions.
#
#
# # Impressions Comparison:
#
# 'Photo' content generates an overwhelmingly higher number of impressions compared to the other content types. It has a remarkably broader reach.
# 'Video' content is the second-highest in terms of impressions (approximately 2,213,793), suggesting that video content is also highly effective in reaching a substantial audience.
# 'Text' content and 'Link' content types have moderate impressions, indicating that well-crafted textual posts and shared links can also achieve a reasonable level of impressions.
#
# # Content Strategy Insights:
#
# 'Photo' content type is exceptionally effective in terms of impressions, demonstrating its ability to reach a vast audience.
# 'Video' content follows 'Photo' in terms of impressions, suggesting that multimedia content is also engaging and generates considerable impressions.
# 'Text' and 'Link' content types have moderate impressions, indicating that well-written text-based posts and shared links can attract a respectable level of impressions.
#
# In summary, the technical analysis of this data highlights the dominance of 'Photo' and 'Video' content in terms of impressions, indicating that visual and multimedia content types are highly effective in reaching a broad audience. However, there is room for diversification and optimization of content strategies, particularly for 'Text' and 'Link' content types. Understanding audience preferences and continuously refining content strategies can lead to improved impressions and engagement levels.

# %%
# The Total Viral Impressions on Facebook

# %%
Facebook_Viral_Impression_sums = data_facebook.groupby('Content_Type')['Viral_Impressions'].sum().reset_index()

# %%
Facebook_Viral_Impression_sums
# Out:
#   Content_Type  Viral_Impressions
# 0         Link            36345.0
# 1        Photo          5200313.0
# 2         Text           150821.0
# 3        Video           154239.0

# %%
plt.figure(figsize=(10, 6))  # Optional: Set the figure size

plt.bar(Facebook_Viral_Impression_sums['Content_Type'], Facebook_Viral_Impression_sums['Viral_Impressions'], color='blue')
plt.xlabel('Content_Type')
plt.ylabel('Sum of Viral Impressions')
plt.title('Viral Impressions for each facebook content')
plt.xticks(rotation=45)


plt.savefig('large_plot.png', dpi=300)

# %% [markdown]
# # INSIGHTS
#
# # Content-Type Analysis:
#
# The dataset includes four different content types: 'Link,' 'Photo,' 'Text,' and 'Video.'
# 'Photo' content stands out with the highest number of viral impressions (approximately 5,200,313), indicating that photo-based content has a significant viral reach.
#
# # Viral Impressions Comparison:
#
# 'Photo' content generates a substantially higher number of viral impressions compared to the other content types. It has a remarkable viral reach.
# 'Video' content is the second-highest in terms of viral impressions (approximately 154,239), suggesting that video content also has the potential to go viral and reach a significant audience.
# 'Text' and 'Link' content types have relatively lower viral impressions, indicating that these types of content may have a more limited viral reach.
#
# # Content Strategy Insights:
#
# 'Photo' content type is exceptionally effective in generating viral impressions, highlighting its potential to reach a broad and viral audience.
# 'Video' content follows 'Photo' in terms of viral impressions, indicating that multimedia content, especially videos, can also have viral potential.
# 'Text' and 'Link' content types have comparatively lower viral impressions, suggesting that these types of content may need optimization or may be more suitable for specific purposes.
#
# In summary, the technical analysis of this data highlights the dominance of 'Photo' and 'Video' content in terms of viral impressions, indicating their strong potential to go viral and reach a broad audience. However, there is room for diversification and optimization of content strategies, particularly for 'Text' and 'Link' content types, to enhance their viral potential. Understanding audience preferences and continuously refining content strategies can contribute to achieving viral success.

# %%
# The Total Non Viral Impressions on Facebook

# %%
Facebook_Non_Viral_Impression_sums = data_facebook.groupby('Content_Type')['Non_viral_Impressions'].sum().reset_index()

# %%
Facebook_Non_Viral_Impression_sums
# Out:
#   Content_Type  Non_viral_Impressions
# 0         Link               325351.0
# 1        Photo             42245534.0
# 2         Text              1920413.0
# 3        Video              2059537.0

# %%
plt.figure(figsize=(10, 6))  # Optional: Set the figure size

plt.bar(Facebook_Non_Viral_Impression_sums['Content_Type'], Facebook_Non_Viral_Impression_sums['Non_viral_Impressions'], color='blue')
plt.xlabel('Content_Type')
plt.ylabel('Sum of Non_viral_Impressions')
plt.title('Non viral Impressions for each facebook content')
plt.xticks(rotation=45)


plt.savefig('large_plot.png', dpi=300)

# %% [markdown]
# # INSIGHTS
#
# ## Content-Type Analysis:
#
# The dataset includes four different content types: 'Link,' 'Photo,' 'Text,' and 'Video.'
# 'Photo' content stands out with the highest number of non-viral impressions (approximately 42,245,534), indicating that photo-based content consistently generates a substantial number of impressions
#
# ## Non-viral Impressions Comparison:
#
# 'Photo' content generates significantly more non-viral impressions compared to the other content types. It has a considerable reach even outside of viral contexts.
# 'Video' content is the second-highest in terms of non-viral impressions (approximately 2,059,537), suggesting that video content also has a substantial reach in non-viral scenarios.
# 'Text' and 'Link' content types have relatively lower non-viral impressions, indicating that these types of content may have a more limited reach when not going viral
#
# ## Content Strategy Insights:
#
# 'Photo' content type is exceptionally effective in generating non-viral impressions, indicating that photo-based posts consistently reach a wide audience.
# 'Video' content follows 'Photo' in terms of non-viral impressions, highlighting the reach of multimedia content even in non-viral situations.
# 'Text' and 'Link' content types have comparatively lower non-viral impressions, suggesting that these types of content may need optimization or may have a more niche audience.
#
# In summary, the technical analysis of this data highlights the dominance of 'Photo' and 'Video' content in terms of non-viral impressions, indicating their consistent reach even outside of viral contexts. However, there is room for diversification and optimization of content strategies, particularly for 'Text' and 'Link' content types, to enhance their non-viral reach. Understanding audience preferences and continuously refining content strategies can contribute to achieving broader non-viral success.

# %%
Facebook_Fan_Impression_sums = data_facebook.groupby('Content_Type')['Fan_Impressions'].sum().reset_index()

# %%
Facebook_Fan_Impression_sums
# Out:
#   Content_Type  Fan_Impressions
# 0         Link         314154.0
# 1        Photo       40068978.0
# 2         Text        1827391.0
# 3        Video        1538265.0

# %%
plt.figure(figsize=(10, 6))  # Optional: Set the figure size

plt.bar(Facebook_Fan_Impression_sums['Content_Type'], Facebook_Fan_Impression_sums['Fan_Impressions'], color='blue')
plt.xlabel('Content_Type')
plt.ylabel('Sum of Fan_Impressions')
plt.title('Fan Impressions for each facebook content')
plt.xticks(rotation=45)


plt.savefig('large_plot.png', dpi=300)

# %% [markdown]
# # INSIGHTS
#
# ## Content-Type Analysis:
#
# The dataset includes four different content types: 'Link,' 'Photo,' 'Text,' and 'Video.'
# 'Photo' content stands out with the highest number of fan impressions (approximately 40,068,978), indicating that photo-based content consistently generates a substantial number of impressions among the fan base
#
# ## Fan Impressions Comparison:
#
# 'Photo' content generates significantly more fan impressions compared to the other content types. It demonstrates a strong and consistent appeal to the existing fan base.
# 'Video' content is the second-highest in terms of fan impressions (approximately 1,538,265), suggesting that video content is also effective in engaging and impressing the existing fan base.
# 'Text' and 'Link' content types have relatively lower fan impressions, suggesting that these types of content may have a more limited impact on the existing fan base.
#
#
# ## Content Strategy Insights:
#
# 'Photo' content type excels in generating fan impressions, indicating that visual content, particularly photos, consistently engages and impresses the existing fan base.
# 'Video' content follows 'Photo' in terms of fan impressions, highlighting the power of multimedia content, including videos, in maintaining strong engagement with the fan base.
# 'Text' and 'Link' content types have comparatively lower fan impressions, indicating that these types of content may require optimization or may not resonate as strongly with the existing fan base.
#
#
# In summary, the technical analysis of this data highlights the dominance of 'Photo' and 'Video' content in terms of fan impressions, indicating their consistent and strong engagement with the existing fan base. However, there is room for diversification and optimization of content strategies, particularly for 'Text' and 'Link' content types, to enhance their impact on the fan base. Understanding fan preferences and continually refining content strategies can contribute to maintaining and strengthening fan engagement.

# %%
Facebook_Non_fan_Impressions_sums = data_facebook.groupby('Content_Type')['Non_fan_Impressions'].sum().reset_index()

# %%
Facebook_Non_fan_Impressions_sums
# Out:
#   Content_Type  Non_fan_Impressions
# 0         Link              47564.0
# 1        Photo            7377027.0
# 2         Text             243843.0
# 3        Video             675528.0

# %%
plt.figure(figsize=(10, 6))  # Optional: Set the figure size

plt.bar(Facebook_Non_fan_Impressions_sums['Content_Type'], Facebook_Non_fan_Impressions_sums['Non_fan_Impressions'], color='blue')
plt.xlabel('Content_Type')
plt.ylabel('Sum of Facebook_Non_fan_Impressions_sums')
plt.title('Facebook Non fan Impressions  for each facebook content')
plt.xticks(rotation=45)


plt.savefig('large_plot.png', dpi=300)

# %% [markdown]
# # INSIGHTS
#
# ## Content-Type Analysis:
#
# The dataset includes four different content types: 'Link,' 'Photo,' 'Text,' and 'Video.'
# 'Photo' content stands out with the highest number of non-fan impressions (approximately 7,377,027), indicating that photo-based content consistently generates a substantial number of impressions even among non-fans
#
# ## Non-fan Impressions Comparison:
#
# 'Photo' content generates significantly more non-fan impressions compared to the other content types. It demonstrates strong appeal and reach beyond the existing fan base.
# 'Video' content is the second-highest in terms of non-fan impressions (approximately 675,528), suggesting that video content is also effective in reaching and impressing non-fans.
# 'Text' and 'Link' content types have relatively lower non-fan impressions, indicating that these types of content may have a more limited impact on non-fans
#
# ## Content Strategy Insights:
#
# 'Photo' content type excels in generating non-fan impressions, indicating that visual content, particularly photos, consistently reaches a wide audience, including those who are not fans of the content.
# 'Video' content follows 'Photo' in terms of non-fan impressions, highlighting the power of multimedia content, including videos, in attracting non-fans.
# 'Text' and 'Link' content types have comparatively lower non-fan impressions, suggesting that these types of content may need optimization or may not resonate as strongly with non-fans
#
#
# In summary, the technical analysis of this data highlights the dominance of 'Photo' and 'Video' content in terms of non-fan impressions, indicating their consistent and broad reach even among non-fans. However, there is room for diversification and optimization of content strategies, particularly for 'Text' and 'Link' content types, to enhance their impact on non-fans. Understanding the preferences of non-fans and continually refining content strategies can contribute to expanding the audience and improving engagement with non-fans.

# %%
Facebook_Reach_sums = data_facebook.groupby('Content_Type')['Reach'].sum().reset_index()

# %%
Facebook_Reach_sums
# Out:
#   Content_Type       Reach
# 0         Link    306814.0
# 1        Photo  42029710.0
# 2         Text   1946893.0
# 3        Video   2054823.0

# %%
plt.figure(figsize=(10, 6))  # Optional: Set the figure size

plt.bar(Facebook_Reach_sums['Content_Type'], Facebook_Reach_sums['Reach'], color='blue')
plt.xlabel('Content_Type')
plt.ylabel('Sum of Reach')
plt.title('Reach  for each facebook content')
plt.xticks(rotation=45)


plt.savefig('large_plot.png', dpi=300)

# %% [markdown]
# # INSIGHTS
#
# ## Content-Type Analysis:
#
# The dataset includes four different content types: 'Link,' 'Photo,' 'Text,' and 'Video.'
# 'Photo' content stands out with the highest reach (approximately 42,029,710), indicating that photo-based content consistently reaches a substantial audience.
#
# ## Reach Comparison:
#
# 'Photo' content generates significantly more reach compared to the other content types. It demonstrates a strong and consistent ability to engage and reach a broad audience.
# 'Video' content is the second-highest in terms of reach (approximately 2,054,823), suggesting that video content is also effective in engaging and reaching a wide audience.
# 'Text' and 'Link' content types have relatively lower reach, indicating that these types of content may have a more limited impact on audience reach.
#
# ## Content Strategy Insights:
#
# 'Photo' content type excels in generating reach, indicating that visual content, particularly photos, consistently engages and impresses a broad audience.
# 'Video' content follows 'Photo' in terms of reach, highlighting the power of multimedia content, including videos, in reaching a wide audience.
# 'Text' and 'Link' content types have comparatively lower reach, suggesting that these types of content may need optimization or may not resonate as strongly with a broad audience.
#
# In summary, the technical analysis of this data highlights the dominance of 'Photo' and 'Video' content in terms of reach, indicating their consistent and strong ability to engage and reach a broad audience. However, there is room for diversification and optimization of content strategies, particularly for 'Text' and 'Link' content types, to enhance their audience reach. Understanding audience preferences and continually refining content strategies can contribute to achieving broader audience engagement and reach.

# %%
Facebook_Viral_Reach_sums = data_facebook.groupby('Content_Type')['Viral_Reach'].sum().reset_index()

# %%
Facebook_Viral_Reach_sums
# Out:
#   Content_Type  Viral_Reach
# 0         Link      25677.0
# 1        Photo    3754558.0
# 2         Text     134747.0
# 3        Video     134090.0

# %%
plt.figure(figsize=(10, 6))  # Optional: Set the figure size

plt.bar(Facebook_Viral_Reach_sums['Content_Type'], Facebook_Viral_Reach_sums['Viral_Reach'], color='blue')
plt.xlabel('Content_Type')
plt.ylabel('Sum of Viral_Reach')
plt.title('Viral Reach  for each facebook content')
plt.xticks(rotation=45)


plt.savefig('large_plot.png', dpi=300)

# %% [markdown]
# # INSIGHTS
#
# ## Content-Type Analysis:
#
# The dataset includes four different content types: 'Link,' 'Photo,' 'Text,' and 'Video.'
# 'Photo' content stands out with the highest viral reach (approximately 3,754,558), indicating that photo-based content consistently generates a substantial number of viral impressions.
#
# ## Viral Reach Comparison:
#
# 'Photo' content generates significantly more viral reach compared to the other content types. It demonstrates a strong and consistent ability to engage and reach a broad audience in viral scenarios.
# 'Video' content is the second-highest in terms of viral reach (approximately 134,090), suggesting that video content is also effective in attracting viral attention.
# 'Text' and 'Link' content types have relatively lower viral reach, indicating that these types of content may have a more limited impact in going viral
#
#
# ## Content Strategy Insights:
#
# 'Photo' content type excels in generating viral reach, indicating that visual content, particularly photos, consistently captures the attention of a broad audience in viral scenarios.
# 'Video' content follows 'Photo' in terms of viral reach, highlighting the power of multimedia content, including videos, in going viral.
# 'Text' and 'Link' content types have comparatively lower viral reach, suggesting that these types of content may need optimization or may not resonate as strongly in viral contexts.
#
# In summary, the technical analysis of this data highlights the dominance of 'Photo' and 'Video' content in terms of viral reach, indicating their consistent and strong ability to capture viral attention. However, there is room for diversification and optimization of content strategies, particularly for 'Text' and 'Link' content types, to enhance their viral reach. Understanding the factors driving virality and continually refining content strategies can contribute to achieving broader viral success.

# %%
Facebook_Non_viral_Reach_sums = data_facebook.groupby('Content_Type')['Non_viral_Reach'].sum().reset_index()

# %%
Facebook_Non_viral_Reach_sums
# Out:
#   Content_Type  Non_viral_Reach
# 0         Link         282665.0
# 1        Photo       38418426.0
# 2         Text        1821547.0
# 3        Video        1929080.0

# %%
plt.figure(figsize=(10, 6))  # Optional: Set the figure size

plt.bar(Facebook_Non_viral_Reach_sums['Content_Type'], Facebook_Non_viral_Reach_sums['Non_viral_Reach'], color='blue')
plt.xlabel('Content_Type')
plt.ylabel('Sum of Non_viral_Reach')
plt.title('Non_viral_Reach for each facebook content')
plt.xticks(rotation=45)


plt.savefig('large_plot.png', dpi=300)

# %% [markdown]
# # INSIGHTS
#
# ## Content-Type Analysis:
#
# The dataset includes four different content types: 'Link,' 'Photo,' 'Text,' and 'Video.'
# 'Photo' content stands out with the highest non-viral reach (approximately 38,418,426), indicating that photo-based content consistently generates a substantial number of impressions, even without going viral.
#
# ## Non-viral Reach Comparison:
#
# 'Photo' content generates significantly more non-viral reach compared to the other content types. It demonstrates strong and consistent appeal to the audience, regardless of whether it goes viral.
# 'Video' content is the second-highest in terms of non-viral reach (approximately 1,929,080), suggesting that video content is also effective in reaching and engaging the audience.
# 'Text' and 'Link' content types have relatively lower non-viral reach, indicating that these types of content may have a more limited impact on the audience when not going viral.
#
# ## Content Strategy Insights:
#
# 'Photo' content type excels in generating non-viral reach, indicating that visual content, particularly photos, consistently captures the attention of the audience, even without going viral.
# 'Video' content follows 'Photo' in terms of non-viral reach, highlighting the power of multimedia content, including videos, in engaging the audience.
# 'Text' and 'Link' content types have comparatively lower non-viral reach, suggesting that these types of content may need optimization or may not resonate as strongly with the audience when not going viral.
#
# In summary, the technical analysis of this data highlights the dominance of 'Photo' and 'Video' content in terms of non-viral reach, indicating their consistent and strong ability to engage the audience, even without going viral. However, there is room for diversification and optimization of content strategies, particularly for 'Text' and 'Link' content types, to enhance their non-viral reach. Understanding audience preferences and continually refining content strategies can contribute to achieving broader audience engagement.

# %%
Facebook_Fan_Reach_sums = data_facebook.groupby('Content_Type')['Fan_Reach'].sum().reset_index()

# %%
Facebook_Fan_Reach_sums
# Out:
#   Content_Type   Fan_Reach
# 0         Link    270190.0
# 1        Photo  36093856.0
# 2         Text   1727850.0
# 3        Video   1412242.0

# %%
plt.figure(figsize=(10, 6))  # Optional: Set the figure size

plt.bar(Facebook_Fan_Reach_sums['Content_Type'], Facebook_Fan_Reach_sums['Fan_Reach'], color='blue')
plt.xlabel('Content_Type')
plt.ylabel('Sum of Fan_Reach')
plt.title('Fan Reach for each facebook content')
plt.xticks(rotation=45)


plt.savefig('large_plot.png', dpi=300)

# %% [markdown]
# # INSIGHTS
#
# ## Content-Type Analysis:
#
# The dataset includes four different content types: 'Link,' 'Photo,' 'Text,' and 'Video.'
# 'Photo' content stands out with the highest fan reach (approximately 36,093,856), indicating that photo-based content consistently generates a substantial number of impressions among the existing fan base.
#
# ## Fan Reach Comparison:
#
# 'Photo' content generates significantly more fan reach compared to the other content types. It demonstrates strong and consistent appeal to the existing fan base.
# 'Video' content is the second-highest in terms of fan reach (approximately 1,412,242), suggesting that video content is also effective in engaging and reaching the existing fan base.
# 'Text' and 'Link' content types have relatively lower fan reach, indicating that these types of content may have a more limited impact among the existing fan base.
#
# ## Content Strategy Insights:
#
# 'Photo' content type excels in generating fan reach, indicating that visual content, particularly photos, consistently engages and impresses the existing fan base.
# 'Video' content follows 'Photo' in terms of fan reach, highlighting the power of multimedia content, including videos, in engaging the existing fan base.
# 'Text' and 'Link' content types have comparatively lower fan reach, suggesting that these types of content may need optimization or may not resonate as strongly with the existing fan base.
#
# In summary, the technical analysis of this data highlights the dominance of 'Photo' and 'Video' content in terms of fan reach, indicating their consistent and strong ability to engage the existing fan base. However, there is room for diversification and optimization of content strategies, particularly for 'Text' and 'Link' content types, to enhance their reach and engagement among existing fans. Understanding the preferences of the fan base and continually refining content strategies can contribute to maintaining and growing a loyal audience.

# %%
#Impressions and Viral Impressions between content on facebook

content_types =data_facebook['Content_Type'].unique()

# Create a scatter plot for each content type
plt.figure(figsize=(10, 9))

for content_type in content_types:
    content_data = data_facebook[data_facebook['Content_Type'] == content_type]
    plt.scatter(content_data['Impressions'], content_data['Viral_Impressions'], label=content_type)

plt.xlabel('Impressions')
plt.ylabel('Viral_Impressions')
plt.title('Impressions and Viral Impressions between content on facebook')
plt.legend(title='Content_Type')

plt.show()


#Impressions and Non Viral Impressions between content on facebook

content_types =data_facebook['Content_Type'].unique()

# Create a scatter plot for each content type
plt.figure(figsize=(10, 9))

for content_type in content_types:
    content_data = data_facebook[data_facebook['Content_Type'] == content_type]
    plt.scatter(content_data['Impressions'], content_data['Non_viral_Impressions'], label=content_type)

plt.xlabel('Impressions')
plt.ylabel('Non_viral_Impressions')
plt.title('Impressions and Non Viral Impressions between content on facebook')
plt.legend(title='Content_Type')

plt.show()

#Impressions and Fan Impressions between content on facebook

content_types =data_facebook['Content_Type'].unique()

# Create a scatter plot for each content type
plt.figure(figsize=(10, 9))

for content_type in content_types:
    content_data = data_facebook[data_facebook['Content_Type'] == content_type]
    plt.scatter(content_data['Impressions'], content_data['Fan_Impressions'], label=content_type)

plt.xlabel('Impressions')
plt.ylabel('Fan_Impressions')
plt.title('Impressions and Fan Impressions between content on facebook')
plt.legend(title='Content_Type')

plt.show()

# Impressions and Non Fan Impressions between content on facebook

content_types =data_facebook['Content_Type'].unique()

# Create a scatter plot for each content type
plt.figure(figsize=(10, 9))

for content_type in content_types:
    content_data = data_facebook[data_facebook['Content_Type'] == content_type]
    plt.scatter(content_data['Impressions'], content_data['Non_fan_Impressions'], label=content_type)

plt.xlabel('Impressions')
plt.ylabel('Non_fan_Impressions')
plt.title('Impressions and Non Fan Impressions between content on facebook')
plt.legend(title='Content_Type')

plt.show()

# Engagements and Reach between content on facebook

# Create a scatter plot for each content type
plt.figure(figsize=(10, 9))

for content_type in content_types:
    content_data = data_facebook[data_facebook['Content_Type'] == content_type]
    plt.scatter(content_data['Engagements'], content_data['Reach'], label=content_type)

plt.xlabel('Engagements')
plt.ylabel('Reach')
plt.title('Engagements and Reach between content on facebook')
plt.legend(title='Content_Type')

plt.show()

# Engagements and Viral Reach between content on facebook

# Create a scatter plot for each content type
plt.figure(figsize=(10, 9))

for content_type in content_types:
    content_data = data_facebook[data_facebook['Content_Type'] == content_type]
    plt.scatter(content_data['Engagements'], content_data['Viral_Reach'], label=content_type)

plt.xlabel('Engagements')
plt.ylabel('Viral_Reach')
plt.title('Engagements and Viral Reach between content on facebook')
plt.legend(title='Content_Type')

plt.show()

#Engagements and Non_viral_Reach between content on facebook

# Create a scatter plot for each content type
plt.figure(figsize=(10, 9))

for content_type in content_types:
    content_data = data_facebook[data_facebook['Content_Type'] == content_type]
    plt.scatter(content_data['Engagements'], content_data['Non_viral_Reach'], label=content_type)

plt.xlabel('Engagements')
plt.ylabel('Non_viral_Reach')
plt.title('Engagements and Non_viral_Reach between content on facebook')
plt.legend(title='Content_Type')

plt.show()

#Engagements and Fan_Reach between content on facebook

# Create a scatter plot for each content type
plt.figure(figsize=(10, 9))

for content_type in content_types:
    content_data = data_facebook[data_facebook['Content_Type'] == content_type]
    plt.scatter(content_data['Engagements'], content_data['Fan_Reach'], label=content_type)

plt.xlabel('Engagements')
plt.ylabel('Fan_Reach')
plt.title('Engagements and Fan_Reach between content on facebook')
plt.legend(title='Content_Type')

plt.show()

# %%
color_discrete_map = {
    'Photo': 'Green',
    'Video': 'Cividis',
    'Text': 'Paired',
    'Link': 'Viridis'
}

# Create a treemap with custom colors
fig = px.treemap(data_facebook, 
                 path=['Content_Type'], 
                 values='Reactions',
                 color='Content_Type',
                 color_discrete_map=color_discrete_map,  # Assign custom colors
                 hover_data=['Likes','Comments', 'Shares'], 
                 title='Distribution of reactions between all content on Facebook')

fig.show()


color_discrete_map = {
    'Photo': 'Green',
    'Video': 'Cividis',
    'Text': 'Paired',
    'Link': 'Viridis'
}

# Create a treemap with custom colors
fig = px.treemap(data_facebook, 
                 path=['Content_Type'], 
                 values='Likes',
                 color='Content_Type',
                 color_discrete_map=color_discrete_map,  # Assign custom colors
                 hover_data=['Reactions','Comments', 'Shares'], 
                 title='Distribution of reactions between all content on Facebook')

fig.show()


color_discrete_map = {
    'Photo': 'Green',
    'Video': 'Cividis',
    'Text': 'Paired',
    'Link': 'Viridis'
}

# Create a treemap with custom colors
fig = px.treemap(data_facebook, 
                 path=['Content_Type'], 
                 values='Comments',
                 color='Content_Type',
                 color_discrete_map=color_discrete_map,  # Assign custom colors
                 hover_data=['Reactions','Likes', 'Shares'], 
                 title='Distribution of reactions between all content on Facebook')

fig.show()



color_discrete_map = {
    'Photo': 'Green',
    'Video': 'Cividis',
    'Text': 'Paired',
    'Link': 'Viridis'
}

# Create a treemap with custom colors
fig = px.treemap(data_facebook, 
                 path=['Content_Type'], 
                 values='Shares',
                 color='Content_Type',
                 color_discrete_map=color_discrete_map,  # Assign custom colors
                 hover_data=['Reactions','Likes', 'Comments'], 
                 title='Distribution of reactions between all content on Facebook')

fig.show()
# Out:
# <div>                            <div id="1a1b5fe1-bcb2-4607-abd2-5e445c9f4977" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a1b5fe1-bcb2-4607-abd2-5e445c9f4977")) {                    Plotly.newPlot(                        "1a1b5fe1-bcb2-4607-abd2-5e445c9f4977",                        [{"branchvalues":"total","customdata":[["(?)","(?)","(?)","Photo"],["(?)","(?)","(?)","Text"],["(?)","(?)","(?)","Video"],["(?)","(?)","(?)","Link"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Reactions=%{value}<br>parent=%{parent}<br>id=%{id}<br>Likes=%{customdata[0]}<br>Comments=%{customdata[1]}<br>Shares=%{customdata[2]}<br>Content_Type=%{customdata[3]}<extra></extra>","ids":["Photo","Text","Video","Link"],"labels":["Photo","Text
# ...

# %%
correlation_matrix = data_facebook[['Viral_Impressions', 'Impressions']].corr()
# Extract the correlation between 'Impressions' and 'Engagements'
correlation = correlation_matrix.loc['Viral_Impressions', 'Impressions']

# Create a heatmap (correlogram) for the entire correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation between Viral Impressions and Impressions on Facebook')
plt.show()

# Display the correlation value between 'Impressions' and 'Engagements'
print(f'Correlation between Viral Impressions and Impressions Facebook : {correlation}')




correlation_matrix = data_facebook[['Non_viral_Impressions', 'Impressions']].corr()
# Extract the correlation between 'Impressions' and 'Engagements'
correlation = correlation_matrix.loc['Non_viral_Impressions', 'Impressions']

# Create a heatmap (correlogram) for the entire correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation between Non viral Impressions and Impressions on Facebook')
plt.show()

# Display the correlation value between 'Impressions' and 'Engagements'
print(f'Correlation between Non_viral_Impressions and Impressions Facebook : {correlation}')



correlation_matrix = data_facebook[['Fan_Impressions', 'Impressions']].corr()
# Extract the correlation between 'Impressions' and 'Engagements'
correlation = correlation_matrix.loc['Fan_Impressions', 'Impressions']

# Create a heatmap (correlogram) for the entire correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation between Fan Impressions and Impressions on Facebook')
plt.show()

# Display the correlation value between 'Impressions' and 'Engagements'
print(f'Correlation between Fan Impressions and Impressions Facebook : {correlation}')



correlation_matrix = data_facebook[['Non_fan_Impressions', 'Impressions']].corr()
# Extract the correlation between 'Impressions' and 'Engagements'
correlation = correlation_matrix.loc['Non_fan_Impressions', 'Impressions']

# Create a heatmap (correlogram) for the entire correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation between Non fan Impressions and Impressions on Facebook')
plt.show()

# Display the correlation value between 'Impressions' and 'Engagements'
print(f'Correlation between Non fan Impressions and Impressions Facebook : {correlation}')


correlation_matrix = data_facebook[['Reach', 'Viral_Reach']].corr()
# Extract the correlation between 'Impressions' and 'Engagements'
correlation = correlation_matrix.loc['Reach', 'Viral_Reach']

# Create a heatmap (correlogram) for the entire correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation between  Reach and Viral_Reach on Facebook')
plt.show()

# Display the correlation value between 'Impressions' and 'Engagements'
print(f'Correlation between  Reach and Viral_Reach Facebook : {correlation}')


correlation_matrix = data_facebook[['Reach', 'Non_viral_Reach']].corr()
# Extract the correlation between 'Impressions' and 'Engagements'
correlation = correlation_matrix.loc['Reach', 'Non_viral_Reach']

# Create a heatmap (correlogram) for the entire correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation between  Reach and Non_viral_Reach on Facebook')
plt.show()

# Display the correlation value between 'Impressions' and 'Engagements'
print(f'Correlation between  Reach and Non_viral_Reach Facebook : {correlation}')


correlation_matrix = data_facebook[['Reach', 'Fan_Reach']].corr()
# Extract the correlation between 'Impressions' and 'Engagements'
correlation = correlation_matrix.loc['Reach', 'Fan_Reach']

# Create a heatmap (correlogram) for the entire correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation between  Reach and Fan_Reach on Facebook')
plt.show()

# Display the correlation value between 'Impressions' and 'Engagements'
print(f'Correlation between  Reach and Fan_Reach Facebook : {correlation}')


correlation_matrix = data_facebook[['Engagements', 'Engaged_Users']].corr()
# Extract the correlation between 'Impressions' and 'Engagements'
correlation = correlation_matrix.loc['Engagements', 'Engaged_Users']

# Create a heatmap (correlogram) for the entire correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation between  Engagements and Engaged_Users on Facebook')
plt.show()

# Display the correlation value between 'Impressions' and 'Engagements'
print(f'Correlation between  Engagements and Engaged_Users Facebook : {correlation}')


correlation_matrix = data_facebook[['Engagements', 'Engaged_Fans']].corr()
# Extract the correlation between 'Impressions' and 'Engagements'
correlation = correlation_matrix.loc['Engagements', 'Engaged_Fans']

# Create a heatmap (correlogram) for the entire correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation between  Engagements and Engaged_Fans on Facebook')
plt.show()

# Display the correlation value between 'Impressions' and 'Engagements'
print(f'Correlation between  Engagements and Engaged_Fans Facebook : {correlation}')
# Out:
# Correlation between Viral Impressions and Impressions Facebook : 0.6533493032984776
# Correlation between Non_viral_Impressions and Impressions Facebook : 0.980384724887032
# Correlation between Fan Impressions and Impressions Facebook : 0.9164032408841667
# Correlation between Non fan Impressions and Impressions Facebook : 0.6614735799919154
# Correlation between  Reach and Viral_Reach Facebook : 0.6091429767857269
# Correlation between  Reach and Non_viral_Reach Facebook : 0.9872406370186549
# Correlation between  Reach and Fan_Reach Facebook : 0.8976064872157831
# Correlation between  Engagements and Engaged_Users Facebook : 0.31195567150487935
# Correlation between  Engagements and Engaged_Fans Facebook : 0.30139802033617946

# %% [markdown]
# # INSIGHTS
#
# ## Correlation between Viral Impressions and Impressions Facebook
#
# ## Positive Correlation:
# A correlation coefficient value of 0.653 is positive, which means that as one variable increases, the other tends to increase as well. In this case, as "Viral Impressions" increase, "Impressions" also tend to increase
#
# ## Strong Correlation:
# The value of 0.653 suggests a relatively strong correlation between the two variables. This implies that there is a consistent pattern or trend in their relationship.
#
# ## Interpretation: In the context of Facebook metrics:
#
# "Impressions" typically represent the total number of times a piece of content is displayed to users on their screens.
# "Viral Impressions" are impressions that occur when people see a post or content shared by someone else on Facebook. They are a subset of total impressions.
# The strong positive correlation between "Viral Impressions" and "Impressions" indicates that when content goes viral and is shared by users, it tends to significantly increase the overall number of impressions. In other words, content that is widely shared and becomes viral attracts a larger audience and results in more total impressions.
#
# ## Practical Implications:
#
# Content Strategy: Marketers and content creators can use this insight to develop strategies that encourage users to share their content. Creating highly shareable and engaging content can lead to more viral impressions and a broader reach.
# Virality Impact: Understanding the impact of virality on total impressions can help businesses assess the effectiveness of their social media campaigns and identify which content resonates most with their audience.
#
# In summary, the positive and strong correlation between "Viral Impressions" and "Impressions" on Facebook indicates that content that goes viral and is widely shared tends to have a significant positive impact on the total number of impressions. This insight is valuable for optimizing content strategies and maximizing the reach and engagement of Facebook posts.
#
#
# ## Correlation between Non_viral_Impressions and Impressions Facebook
#
# ## High Positive Correlation:
# A correlation coefficient value of 0.980 is very close to 1, which signifies an extremely strong positive correlation. This implies that as one variable increases, the other almost always increases as well. In this case, as "Non_viral_Impressions" increase, "Impressions" also tend to increase significantly.
#
# ## Interpretation: In the context of Facebook metrics:
#
# "Impressions" typically represent the total number of times a piece of content is displayed to users on their screens.
# "Non_viral_Impressions" are impressions that occur through regular distribution channels, excluding viral impressions. They are essentially the impressions generated by content through standard means, not including content that goes viral.
# The extremely high positive correlation between "Non_viral_Impressions" and "Impressions" indicates that there is an almost one-to-one relationship between these two variables. In other words, as content accumulates non-viral impressions, it nearly directly contributes to the total number of impressions.
#
# ## Practical Implications:
#
# Content Reach: This correlation suggests that the majority of impressions on Facebook are generated through regular distribution channels rather than virality. Content creators can focus on optimizing their regular distribution strategies to reach a wider audience.
# Monitoring Performance: Marketers and businesses can use this insight to closely monitor the performance of their non-viral content, as it has a significant impact on the overall reach and visibility of their posts.
#
# In summary, the extremely high positive correlation between "Non_viral_Impressions" and "Impressions" on Facebook indicates that non-viral impressions are the dominant driver of total impressions. This insight underscores the importance of effective content distribution and regular audience engagement in maximizing the reach of content on the platform.
#
#
# # Correlation between Fan Impressions and Impressions Facebook
#
# ## High Positive Correlation:
# A correlation coefficient value of 0.916 is very close to 1, indicating an extremely strong positive correlation. This means that as one variable, "Fan Impressions," increases, the other variable, "Impressions," also tends to increase significantly. There is a strong and consistent pattern in their relationship.
#
# ## Interpretation:In the context of Facebook metrics:
#
# "Impressions" represent the total number of times a piece of content is displayed to users on their screens.
# "Fan Impressions" are impressions generated among the existing fan or follower base of a Facebook page or account.
# The high positive correlation between "Fan Impressions" and "Impressions" suggests that there is a nearly one-to-one relationship between these two variables. In other words, when content is seen by the existing fan base, it significantly contributes to the overall total impressions.
#
# ## Practical Implications:
#
# Engaging the Fan Base: This correlation underscores the importance of maintaining and engaging with an existing fan base or followers. Content that resonates with and is seen by these dedicated followers has a substantial impact on the total reach of posts.
# Audience Retention: Businesses and content creators can focus on strategies to keep their fan base engaged and informed, as this is a crucial factor in maximizing overall impressions.
#
# In summary, the high positive correlation between "Fan Impressions" and "Impressions" on Facebook indicates that engaging and reaching the existing fan or follower base has a significant impact on the total number of impressions. Content that resonates with dedicated followers plays a vital role in extending the reach of posts to a broader audience on the platform.
#
#
# # Correlation between Non fan Impressions and Impressions Facebook
#
# ## Positive Correlation:
# A correlation coefficient value of 0.661 is positive, indicating that as one variable, "Non fan Impressions," increases, the other variable, "Impressions," also tends to increase. While not as strong as some other correlations, it still shows a meaningful pattern in their relationship.
#
# ## Interpretation: In the context of Facebook metrics:
#
# "Impressions" represent the total number of times a piece of content is displayed to users on their screens.
# "Non fan Impressions" are impressions generated outside the existing fan or follower base of a Facebook page or account. They typically result from content distribution to broader audiences.
# The positive correlation between "Non fan Impressions" and "Impressions" suggests that when content is distributed to audiences beyond the existing fan base, it contributes positively to the overall total impressions.
#
# ## Practical Implications:
#
# Broadening Reach: This correlation highlights the importance of reaching and engaging audiences beyond the existing fan base. Content that attracts non-fans can significantly increase the overall reach and visibility of posts.
# Audience Expansion: Marketers and businesses can use this insight to develop strategies aimed at expanding their audience base and targeting specific demographics or interest groups.
#
# In summary, the positive correlation between "Non fan Impressions" and "Impressions" on Facebook indicates that reaching audiences beyond the existing fan base positively impacts the total number of impressions. While not as strong as some other correlations, it underscores the significance of broadening the reach and engaging with a wider audience on the platform to increase overall content visibility.
#
#
# # Correlation between  Reach and Viral_Reach Facebook
#
# ## Positive Correlation:
# A correlation coefficient value of 0.609 is positive, which means that as one variable, "Reach," increases, the other variable, "Viral_Reach," also tends to increase. This suggests that there is a meaningful pattern in their relationship, and when one variable goes up, the other tends to follow suit
#
# ## Interpretation: In the context of Facebook metrics:
#
# "Reach" represents the total number of unique users who have seen a particular piece of content.
# "Viral_Reach" represents the portion of reach that occurs when people see a post or content shared by someone else on Facebook. It is a subset of total reach.
# The positive correlation between "Reach" and "Viral_Reach" indicates that when content reaches a larger audience (total reach increases), there is a higher likelihood of that content being shared by users, resulting in viral reach.
#
# ## Practical Implications:
#
# Content Amplification: This correlation underscores the idea that increasing the initial reach of content can have a cascading effect, leading to more viral reach. Engaging and shareable content has the potential to spread to a broader audience.
# Virality Potential: Marketers and content creators can use this insight to identify content that has the potential to go viral and leverage it to increase overall reach and engagement.
#
# In summary, the positive correlation between "Reach" and "Viral_Reach" on Facebook suggests that increasing the total reach of content is associated with a higher likelihood of that content being shared and going viral. This insight emphasizes the importance of creating content that not only reaches a wide audience but also has the potential to engage users to the point where they share it with their own networks, thereby expanding its reach even further.
#
#
# # Correlation between  Reach and Non_viral_Reach Facebook :
#
# ## Extremely High Positive Correlation:
# A correlation coefficient value of 0.987 is very close to 1, signifying an almost perfect positive correlation. This implies an extraordinarily strong positive relationship, where as one variable, "Reach," increases, the other variable, "Non_viral_Reach," almost always increases in a nearly one-to-one fashion.
#
# ## Interpretation: In the context of Facebook metrics:
#
# "Reach" represents the total number of unique users who have seen a particular piece of content.
# "Non_viral_Reach" represents the portion of reach that occurs through regular distribution channels, excluding viral reach. It is essentially the reach generated by content through standard means, not including content that goes viral.
# The extremely high positive correlation between "Reach" and "Non_viral_Reach" suggests that there is an almost perfect relationship between these two variables. In other words, when content accumulates reach through regular distribution channels, it very closely contributes to the overall total reach.
#
# ## Practical Implications:
#
# Content Amplification: This correlation underscores the idea that increasing the initial reach of content can have a cascading effect, leading to more viral reach. Engaging and shareable content has the potential to spread to a broader audience.
# Virality Potential: Marketers and content creators can use this insight to identify content that has the potential to go viral and leverage it to increase overall reach and engagement.
#
# In summary, the positive correlation between "Reach" and "Viral_Reach" on Facebook suggests that increasing the total reach of content is associated with a higher likelihood of that content being shared and going viral. This insight emphasizes the importance of creating content that not only reaches a wide audience but also has the potential to engage users to the point where they share it with their own networks, thereby expanding its reach even further.
#
#
# # Correlation between  Reach and Fan_Reach Facebook :
#
# ## High Positive Correlation:
# A correlation coefficient value of 0.898 is close to 1, signifying a strong positive correlation. This means that as one variable, "Reach," increases, the other variable, "Fan_Reach," also tends to increase significantly. There is a clear and consistent pattern in their relationship
#
# ## Interpretation: In the context of Facebook metrics:
#
# "Reach" represents the total number of unique users who have seen a particular piece of content.
# "Fan_Reach" represents the portion of reach that occurs among the existing fan or follower base of a Facebook page or account.
# The high positive correlation between "Reach" and "Fan_Reach" suggests that when content reaches a larger audience (total reach increases), it also tends to extend significantly within the existing fan base.
#
# ## Practical Implications:
#
# Fan Engagement: This correlation underscores the importance of engaging with and retaining an existing fan or follower base. Content that resonates with this dedicated audience has a substantial impact on the overall reach of posts.
# Amplifying Reach: Businesses and content creators can leverage their fan base to amplify the reach of their content. Engaging content can trigger users to share it with their own networks, increasing both total reach and fan reach.
#
# In summary, the high positive correlation between "Reach" and "Fan_Reach" on Facebook indicates that reaching a larger audience positively impacts the extension of content within the existing fan or follower base. Content that resonates with dedicated followers plays a vital role in extending the reach of posts to both fans and a broader audience on the platform.
#
# # Correlation between  Engagements and Engaged_Users Facebook :
#
# ## Positive Correlation:
# A correlation coefficient value of 0.312 is positive, indicating that as one variable, "Engagements," increases, the other variable, "Engaged_Users," also tends to increase, albeit not very strongly. This suggests that there is a discernible but not particularly strong pattern in their relationship.
#
# ## Interpretation: In the context of Facebook metrics:
#
# "Engagements" typically represent the total number of interactions or engagements with a piece of content, including likes, comments, shares, etc.
# "Engaged_Users" represent the number of unique users who have engaged with a piece of content.
# The positive correlation between "Engagements" and "Engaged_Users" suggests that when content receives more interactions or engagements, it tends to attract a higher number of unique users who engage with it.
#
# ## Practical Implications:
#
# Engagement Depth: While the correlation is not very strong, it indicates that there is some level of relationship between the overall number of engagements and the unique users who engage. Content creators can analyze this relationship to understand how deep engagement is among their audience.
# Content Analysis: Marketers can use this insight to assess the effectiveness of their content in engaging a broader audience. It may also help identify content that attracts more interactions from a wider range of users.
#
# In summary, the positive correlation between "Engagements" and "Engaged_Users" on Facebook suggests that there is a connection between the overall number of interactions with content and the number of unique users who engage with it. While not a very strong correlation, it still indicates that increasing engagement can potentially lead to a broader audience engagement, though other factors may also be at play.
#
#
# # Correlation between  Engagements and Engaged_Fans Facebook :
#
#
# ## Positive Correlation:
# A correlation coefficient value of 0.301 is positive, signifying that as one variable, "Engagements," increases, the other variable, "Engaged_Fans," also tends to increase, though not very strongly. This suggests that there is a discernible but not particularly strong pattern in their relationship
#
# ## Interpretation: In the context of Facebook metrics:
#
# "Engagements" typically represent the total number of interactions or engagements with a piece of content, including likes, comments, shares, etc.
# "Engaged_Fans" represent the number of unique users who have engaged with a piece of content and are part of the existing fan or follower base of a Facebook page or account.
#
# The positive correlation between "Engagements" and "Engaged_Fans" suggests that when content receives more interactions or engagements, it also tends to attract a higher number of unique users who are already fans or followers of the page
#
#
# ## Practical Implications:
#
# Fan Engagement: While the correlation is not very strong, it indicates that there is some level of connection between the overall number of engagements and the engagement of existing fans. Content creators can use this insight to understand how engaging their content is among their dedicated fan base.
# Content Analysis: Marketers can assess the effectiveness of their content in engaging existing fans and can identify content that resonates particularly well with this audience.
#
# In summary, the positive correlation between "Engagements" and "Engaged_Fans" on Facebook suggests that there is a connection between the overall number of interactions with content and the engagement of existing fans or followers. While not a very strong correlation, it still indicates that increasing engagement can potentially lead to a deeper level of engagement among the existing fan base, though other factors may also influence this relationship.

# %% [markdown]
# # Recommendations:
#
# ## Content Strategy:
# Tailor content strategies to appeal to both existing fans and a broader audience. Create content that is engaging and shareable, as it can significantly amplify reach.
#
# ## Audience Expansion:
# Develop strategies aimed at expanding the audience base on social media platforms. Target specific demographics or interest groups to increase reach.
#
# ## Engage with Fans:
# Continuously engage with and retain the existing fan or follower base. Content creators should focus on creating content that resonates with dedicated followers while still being shareable to reach a wider audience.
#
# ## Assess Content Performance:
# Regularly assess the effectiveness of content in engaging both fans and non-fans. Identify top-performing content and use it as a model for future posts.
#
# ## Distribution Optimization:
# Optimize content distribution strategies to maximize reach through standard distribution channels. Ensure content is distributed to the right audiences at the right times.
#
# ## Experimentation:
# Experiment with different types of content to gauge their performance and audience response. Use data-driven insights to refine content strategies over time.
#
# ## Monitoring and Analytics:
# Continuously monitor social media metrics and analyze them to gain insights into audience behavior and content performance. Make data-driven decisions for content creation and distribution.
#
# In conclusion, an effective social media strategy involves understanding the nuances of different platforms, content types, and audience engagement patterns. By leveraging data-driven insights and implementing the recommended strategies, businesses and content creators can optimize their social media presence, enhance engagement, and expand their reach to a broader and more diverse audience.
